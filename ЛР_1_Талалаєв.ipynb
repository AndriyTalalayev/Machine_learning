# %% [markdown]
# <a href="https://colab.research.google.com/github/AndriyTalalayev/Machine_learning/blob/main/%D0%9B%D0%A0_1_%D0%A2%D0%B0%D0%BB%D0%B0%D0%BB%D0%B0%D1%94%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Був присутній на парі.

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
matrix = np.random.randint(1, 6, size=(3, 3))
matrix
# Out:
# array([[4, 4, 4],
#        [1, 3, 3],
#        [1, 2, 3]])

# %%
np.linalg.det(matrix)
# Out:
# np.float64(7.999999999999998)

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(3456)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(3456)

# %%
np.sum(matrix)
# Out:
# np.int64(25)

# %%
np.max(matrix)
# Out:
# np.int64(4)

# %%
np.min(matrix)
# Out:
# np.int64(1)

# %%
np.mean(matrix)
# Out:
# np.float64(2.7777777777777777)

# %%
np.sqrt(matrix)
# Out:
# array([[2.        , 2.        , 2.        ],
#        [1.        , 1.73205081, 1.73205081],
#        [1.        , 1.41421356, 1.73205081]])

# %%
np.sum(matrix, axis=1).reshape(-1, 1)
# Out:
# array([[12],
#        [ 7],
#        [ 6]])

# %%
matrix.sum(axis=1).reshape(-1, 1)
# Out:
# array([[12],
#        [ 7],
#        [ 6]])

# %%
x = np.matrix([[1, 2], [4, 3]])
x
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
x.sum(axis=1)
# Out:
# matrix([[3],
#         [7]])

# %%
x.sum(axis=1, dtype='float')
# Out:
# matrix([[3.],
#         [7.]])

# %%
vector = np.random.randint(0, 10, size=25)
np.sort(vector)[::-1]
# Out:
# array([9, 9, 6, 6, 5, 5, 4, 4, 4, 4, 3, 3, 3, 3, 3, 2, 1, 1, 1, 1, 1, 1,
#        1, 0, 0])
